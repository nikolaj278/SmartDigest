# %%
from ..config.settings import SESSION_NAME, API_ID, API_HASH
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from ..config.settings import SESSION_NAME, API_ID, API_HASH
#
# ImportError: attempted relative import with no known parent package
